# %%
import pandas as pd

# %%
audible=pd.read_csv('audible_uncleaned.csv')

# %%
audible
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      Narratedby:JesseBernstein              10 hrs    13-01-10  English
# ...                          ...                 ...         ...      ...
# 87484    Narratedby:ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      Narratedby:RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     Narratedby:FleetCooper     6 hrs and 1 min    07-03-17  English
#
#                                stars   price
# 0         5 out of 5 stars34 ratings  468.00
# 1       4.5 out of 5 stars41 ratings  820.00
# 2       4.5 out of 5 stars38 ratings  410.00
# 3       4.5 out of 5 stars12 ratings  615.00
# 4      4.5 out of 5 stars181 ratings  820.00
# ...                              ...     ...
# 87484                  Not rated yet  596.00
# 87485                  Not rated yet  820.00
# 87486                  Not rated yet  938.00
# 87487                  Not rated yet  680.00
# 87488                  Not rated yet  569.00
#
# [87489 rows x 8 columns]

# %% [markdown]
# # About Dataset
# - Introduction
# - With the trend toward audiobooks growing, I gathered this data to understand how the audiobook market has been growing over the years. From authors of audiobooks to release dates, the data represents the important details of audiobooks from 1998 till 2025 (pre-planned releases).
#
# - I have yet to find a great audiobooks dataset and hence the urge to make a dataset that provides us with information on the basics and the history of audiobooks. I look to improve the dataset with more details in the near future.
#
# # Column Breakdown
# - name: Name of the audiobook
# - author: Author of the audiobook
# - narrator: Narrator of the audiobook
# - time: Length of the audiobook
# - releasedate: Release date of the audiobook
# - language: Language of the audiobook
# - stars: No. of stars the audiobook received
# - price: Price of the audiobook in INR
# - ratings: No. of reviews received by the audiobook

# %% [markdown]
# # Issues with dataset
#
#
# ## Manual assesment and automatic assesment
#
# # Quality issues
# - incorrect datatype assigned to time,releasedate,price `validity`
# - in column author "written by:" is written in each cell `consistency`
# - in column narrator "Narratedby:" is written in each cell `consistency`
# - price needs to mentioned in inr `accuracy`
# - time needs to be in minutes or hours `accuracy`
# - "Not rated yet" in stars column instead of 0 or Nan `completness`
# - some values in language column are in lower case `consistency`
# - "out of" and  "stars" in starts column needs to be removed `consistency`
# - duplicate entries are there with same name, author, narrator,language `validity`
# - name in author and narrator there is no space between surname and first name `Consistency`
# - "Narratedby:anonymous" is there in the narrator column `completness`
# - "Writtenby:anonymous" is there in author column `completness`
# - 'Free' mentioned in some places in price column `consistency`
#
# # Tidiness issues
# - stars column data needs to be distributed in stars and ratings column

# %%
audible.duplicated(subset=['name','author','narrator','language']).sum()
# Out:
# 398

# %%
audible.isnull().sum()
# Out:
# name           0
# author         0
# narrator       0
# time           0
# releasedate    0
# language       0
# stars          0
# price          0
# dtype: int64

# %%
audible.describe()
# Out:
#                   name              author              narrator    time  \
# count            87489               87489                 87489   87489
# unique           82767               48374                 29717    2284
# top     The Art of War  Writtenby:矢島雅弘,石橋遊  Narratedby:anonymous  2 mins
# freq                20                 874                  1034     372
#
#        releasedate language          stars   price
# count        87489    87489          87489   87489
# unique        5058       36            665    1011
# top       16-05-18  English  Not rated yet  586.00
# freq           773    61884          72417    5533

# %% [markdown]
# # creating a copy of the dataset

# %%
audible_df=audible.copy()

# %% [markdown]
# ## Cleaning the data

# %% [markdown]
# - Completness issues first

# %%
#code
audible_df['stars']=audible_df['stars'].replace('Not rated yet','0')

# %%
# test
audible_df.sample(10)

# %% [markdown]
# - removing anonymous with no data avaliable

# %%
audible_df['author']=audible_df['author'].replace('Writtenby:Anonymous','No Data Avaliable')
audible_df['author']=audible_df['author'].replace('Writtenby:anonymous','No Data Avaliable')
audible_df['narrator']=audible_df['narrator'].replace('Narratedby:anonymous','No Data Avaliable')
audible_df['narrator']=audible_df['narrator'].replace('Narratedby:Anonymous','No Data Avaliable')

# %%
audible_df[audible_df['narrator']=='No Data Avaliable']
# Out:
#                                      name  \
# 193                          Swamp Sting!
# 723                            The Aeneid
# 724                   Nuclear Distraction
# 725      Beauty and the Dreaded Sea Beast
# 726                        Double Trouble
# ...                                   ...
# 31675  Twelve Steps and Twelve Traditions
# 37316                The Election of 1860
# 37701                             Georgia
# 47176              Nandhi (Tamil Edition)
# 80928             Simple Bike Maintenance
#
#                                                   author           narrator  \
# 193                Writtenby:SebastianFacio,BlakeA.Hoena  No Data Avaliable
# 723    Writtenby:DiegoAgrimbau,MarceloSosa,TrustedTra...  No Data Avaliable
# 724                Writtenby:ChrisEverheart,ArcanaStudio  No Data Avaliable
# 725                Writtenby:OtisFrampton,LouiseSimonson  No Data Avaliable
# 726                  Writtenby:ScottNickel,SteveHarpster  No Data Avaliable
# ...                                                  ...                ...
# 31675                                  No Data Avaliable  No Data Avaliable
# 37316                         Writtenby:JessicaGunderson  No Data Avaliable
# 37701              Writtenby:BridgetParker,JasonKirchner  No Data Avaliable
# 47176                           Writtenby:P.Mathiyalagan  No Data Avaliable
# 80928                            Writtenby:LisaJ.Amstutz  No Data Avaliable
#
#                     time releasedate language stars   price
# 193              11 mins    16-03-22  English     0  105.00
# 723              33 mins    16-03-22  English     0   82.00
# 724              14 mins    16-03-22  English     0  140.00
# 725              14 mins    16-03-22  English     0   82.00
# 726               6 mins    16-03-22  English     0  105.00
# ...                  ...         ...      ...   ...     ...
# 31675  5 hrs and 17 mins    23-01-21  English     0  209.00
# 37316            41 mins    21-02-22  English     0  117.00
# 37701            13 mins    18-03-22  English     0   93.00
# 47176   1 hr and 51 mins    14-02-22    tamil     0   48.00
# 80928             2 mins    21-02-22  English     0   82.00
#
# [1194 rows x 8 columns]

# %% [markdown]
# ## Tidiness issue

# %%
audible_df['stars1']=audible_df['stars'].str.split('stars').str.get(0)
audible_df['rating']=audible_df['stars'].str.split('stars').str.get(1)

# %%
audible_df.drop(columns='stars',inplace=True)
audible_df.rename(columns={'stars1':'stars'},inplace=True)

# %%
audible_df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      Narratedby:JesseBernstein              10 hrs    13-01-10  English
# ...                          ...                 ...         ...      ...
# 87484    Narratedby:ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      Narratedby:RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     Narratedby:FleetCooper     6 hrs and 1 min    07-03-17  English
#
#         price          stars       rating
# 0      468.00    5 out of 5    34 ratings
# 1      820.00  4.5 out of 5    41 ratings
# 2      410.00  4.5 out of 5    38 ratings
# 3      615.00  4.5 out of 5    12 ratings
# 4      820.00  4.5 out of 5   181 ratings
# ...       ...            ...          ...
# 87484  596.00              0          NaN
# 87485  820.00              0          NaN
# 87486  938.00              0          NaN
# 87487  680.00              0          NaN
# 87488  569.00              0          NaN
#
# [87489 rows x 9 columns]

# %% [markdown]
# ## Validity issues

# %% [markdown]
# - duplicate entries are there with same name, author, narrator,language

# %%
audible_df.duplicated(subset=['name','author','narrator','language']).sum()
# Out:
# 398

# %%
audible_df.drop_duplicates(subset=(['name','author','narrator','language']),inplace=True)

# %%
audible_df.duplicated(subset=['name','author','narrator','language']).sum()
# Out:
# 0

# %%
audible_df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      Narratedby:JesseBernstein              10 hrs    13-01-10  English
# ...                          ...                 ...         ...      ...
# 87484    Narratedby:ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      Narratedby:RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     Narratedby:FleetCooper     6 hrs and 1 min    07-03-17  English
#
#         price          stars       rating
# 0      468.00    5 out of 5    34 ratings
# 1      820.00  4.5 out of 5    41 ratings
# 2      410.00  4.5 out of 5    38 ratings
# 3      615.00  4.5 out of 5    12 ratings
# 4      820.00  4.5 out of 5   181 ratings
# ...       ...            ...          ...
# 87484  596.00              0          NaN
# 87485  820.00              0          NaN
# 87486  938.00              0          NaN
# 87487  680.00              0          NaN
# 87488  569.00              0          NaN
#
# [87091 rows x 9 columns]

# %% [markdown]
# ## Accuracy issues
# - price needs to mentioned in inr

# %%
audible_df.sample(5)
# Out:
#                                                     name  \
# 52470                                       Zwei wie wir
# 46332                 A Bound Woman is a Dangerous Thing
# 67367                                  The Lone Assassin
# 28188  El Octavo Habito De la Efectividad a la Grande...
# 82484                           As Far as You'll Take Me
#
#                                                author  \
# 52470           Writtenby:NormFoster,RenéHeinersdorff
# 46332                         Writtenby:DaMarisB.Hill
# 67367  Writtenby:HelmutOrtner,BenjaminRoss-translator
# 28188                        Writtenby:StephenR.Covey
# 82484                           Writtenby:PhilStamper
#
#                                    narrator               time releasedate  \
# 52470      Narratedby:DanaGolombekvonSenden   1 hr and 15 mins    17-02-22
# 46332                   Narratedby:MiaEllis   1 hr and 59 mins    26-03-19
# 67367                Narratedby:TraberBurns  6 hrs and 29 mins    23-02-13
# 28188                Narratedby:AlejoFelipe  2 hrs and 21 mins    09-01-08
# 82484  Narratedby:MichaelCrouch,PhilStamper  8 hrs and 37 mins    09-02-21
#
#       language     price stars rating
# 52470   german    233.00     0    NaN
# 46332  English    227.00     0    NaN
# 67367  English    668.00     0    NaN
# 28188  spanish    585.00     0    NaN
# 82484  English  1,156.00     0    NaN

# %%
audible_df=audible_df.rename(columns={'price':'price(in INR)'})

# %%
audible_df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator                time releasedate language  \
# 0          Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1       Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2          Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3      Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4      Narratedby:JesseBernstein              10 hrs    13-01-10  English
# ...                          ...                 ...         ...      ...
# 87484    Narratedby:ChrisStewart   7 hrs and 34 mins    09-03-17  English
# 87485      Narratedby:RobertFass   10 hrs and 7 mins    21-02-17  English
# 87486       Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
# 87487     Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11  English
# 87488     Narratedby:FleetCooper     6 hrs and 1 min    07-03-17  English
#
#       price(in INR)          stars       rating
# 0            468.00    5 out of 5    34 ratings
# 1            820.00  4.5 out of 5    41 ratings
# 2            410.00  4.5 out of 5    38 ratings
# 3            615.00  4.5 out of 5    12 ratings
# 4            820.00  4.5 out of 5   181 ratings
# ...             ...            ...          ...
# 87484        596.00              0          NaN
# 87485        820.00              0          NaN
# 87486        938.00              0          NaN
# 87487        680.00              0          NaN
# 87488        569.00              0          NaN
#
# [87091 rows x 9 columns]

# %% [markdown]
# - time needs to be in minutes or hours

# %%
import re
def to_minutes(x):
    x = str(x).lower()
    if "less than 1 min" in x:
        return 0
    
    # Extract hours and minutes using regex
    h_match = re.search(r'(\d+)\s*hr', x)
    m_match = re.search(r'(\d+)\s*min', x)
    
    hours = int(h_match.group(1)) if h_match else 0
    minutes = int(m_match.group(1)) if m_match else 0
    
    return hours*60 + minutes
audible_df["time_mins"] = audible_df["time"].apply(to_minutes)

# %%
audible_df.drop(columns='time',inplace=True)
audible_df.rename(columns={'time_mins':'time(mins)'},inplace=True)

# %%
audible_df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator releasedate language price(in INR)  \
# 0          Narratedby:BillLobely    04-08-08  English        468.00
# 1       Narratedby:RobbieDaymond    01-05-18  English        820.00
# 2          Narratedby:DanRussell    06-11-20  English        410.00
# 3      Narratedby:SoneelaNankani    05-10-21  English        615.00
# 4      Narratedby:JesseBernstein    13-01-10  English        820.00
# ...                          ...         ...      ...           ...
# 87484    Narratedby:ChrisStewart    09-03-17  English        596.00
# 87485      Narratedby:RobertFass    21-02-17  English        820.00
# 87486       Narratedby:FloGibson    30-12-16  English        938.00
# 87487     Narratedby:AntonLesser    23-02-11  English        680.00
# 87488     Narratedby:FleetCooper    07-03-17  English        569.00
#
#                stars       rating  time(mins)
# 0        5 out of 5    34 ratings         140
# 1      4.5 out of 5    41 ratings         788
# 2      4.5 out of 5    38 ratings         123
# 3      4.5 out of 5    12 ratings         676
# 4      4.5 out of 5   181 ratings         600
# ...              ...          ...         ...
# 87484              0          NaN         454
# 87485              0          NaN         607
# 87486              0          NaN        1144
# 87487              0          NaN         248
# 87488              0          NaN         361
#
# [87091 rows x 9 columns]

# %% [markdown]
# ## Consistency issue
# - some values in language column are in lower case
# - "out of" and  "stars" in starts column needs to be removed
# - ratings written in column ratings algonside numerical values

# %%
audible_df.sample(5)
# Out:
#                                                     name  \
# 57512                                           Auctions
# 61399                                        僕が親ならこう育てるね
# 79921                        Сказки старого Вильнюса III
# 23522                            Song for the Blue Ocean
# 12826  Learn Spanish - Level 2: Absolute Beginner Spa...
#
#                                           author  \
# 57512  Writtenby:TimothyP.Hubbard,HarryJ.Paarsch
# 61399                             Writtenby:ひろゆき
# 79921                         Writtenby:МаксФрай
# 23522                       Writtenby:CarlSafina
# 12826       Writtenby:InnovativeLanguageLearning
#
#                            narrator releasedate  language price(in INR) stars  \
# 57512          Narratedby:SeanPratt    29-01-16   English        703.00     0
# 61399                Narratedby:中川典    10-12-21  japanese        697.00     0
# 79921      Narratedby:ВладимирОвуор    28-01-22   russian        200.00     0
# 23522        Narratedby:ToddMcLaren    24-02-13   English      1,170.00     0
# 12826  Narratedby:SpanishPod101.com    07-12-10   English        469.00     0
#
#       rating  time(mins)
# 57512    NaN         340
# 61399    NaN         249
# 79921    NaN         685
# 23522    NaN        1467
# 12826    NaN         281

# %%
audible_df['language']=audible_df['language'].str.title()

# %%
audible_df.sample(5)
# Out:
#                             name  \
# 81740  Girls Who Green the World
# 37353          The Wheel of Time
# 2850        American Latin Music
# 56899          Die Nullzinsfalle
# 30104       The Nature of Nature
#
#                                                   author  \
# 81740                                Writtenby:DianaKapp
# 37353                          Writtenby:CarlosCastaneda
# 2850                                Writtenby:MattDoeden
# 56899  Writtenby:RonaldStöferle,RahimTaghizadegan,Gre...
# 30104                                Writtenby:EnricSala
#
#                           narrator releasedate language price(in INR)  \
# 81740  Narratedby:BrittanyPressley    05-04-22  English      1,256.00
# 37353        Narratedby:LuisMoreno    31-10-19  English        351.00
# 2850          Narratedby:Intuitive    18-04-17  English        469.00
# 56899       Narratedby:PeterWolter    03-09-20   German        602.00
# 30104        Narratedby:WillDamron    28-10-20  English        657.00
#
#                stars     rating  time(mins)
# 81740              0        NaN         451
# 37353    5 out of 5   4 ratings         142
# 2850               0        NaN          67
# 56899              0        NaN         480
# 30104  4.5 out of 5   2 ratings         382

# %%
audible_df['stars']=audible_df['stars'].str.split('out').str.get(0)

# %%
audible_df.sample(5)
# Out:
#                                                name  \
# 60297                            Shop Till You Drop
# 58951                                   Emprendedor
# 46227                               Finding Kennedy
# 11884  Chicken Soup for the Soul: Campus Chronicles
# 69727                 How to Use Your Healing Power
#
#                                                   author  \
# 60297                              Writtenby:ElaineViets
# 58951                            Writtenby:ValentínLópez
# 46227                            Writtenby:JacintaHoward
# 11884  Writtenby:JackCanfield,MarkVictorHansen,AmyNew...
# 69727                          Writtenby:Dr.JosephMurphy
#
#                                     narrator releasedate language  \
# 60297                  Narratedby:SarahPesek    28-08-21  English
# 58951               Narratedby:ValentínLópez    09-11-20  Spanish
# 46227  Narratedby:JakobiDiem,WesleighSiobhan    19-11-19  English
# 11884   Narratedby:SarahGrace,MacLeodAndrews    20-08-11  English
# 69727                   Narratedby:SeanPratt    09-09-16  English
#
#       price(in INR) stars rating  time(mins)
# 60297        516.00     0    NaN         573
# 58951        233.00     0    NaN          36
# 46227        703.00     0    NaN         654
# 11884        603.00     0    NaN         586
# 69727        469.00     0    NaN         212

# %%
audible_df['rating']=audible_df['rating'].str.split('ratings').str.get(0)

# %%
audible_df['rating']=audible_df['rating'].str.split('rating').str.get(0)

# %%
audible_df['rating']=audible_df['rating'].fillna(0)

# %%
audible_df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
#                         narrator releasedate language price(in INR) stars  \
# 0          Narratedby:BillLobely    04-08-08  English        468.00    5
# 1       Narratedby:RobbieDaymond    01-05-18  English        820.00  4.5
# 2          Narratedby:DanRussell    06-11-20  English        410.00  4.5
# 3      Narratedby:SoneelaNankani    05-10-21  English        615.00  4.5
# 4      Narratedby:JesseBernstein    13-01-10  English        820.00  4.5
# ...                          ...         ...      ...           ...   ...
# 87484    Narratedby:ChrisStewart    09-03-17  English        596.00     0
# 87485      Narratedby:RobertFass    21-02-17  English        820.00     0
# 87486       Narratedby:FloGibson    30-12-16  English        938.00     0
# 87487     Narratedby:AntonLesser    23-02-11  English        680.00     0
# 87488     Narratedby:FleetCooper    07-03-17  English        569.00     0
#
#       rating  time(mins)
# 0        34          140
# 1        41          788
# 2        38          123
# 3        12          676
# 4       181          600
# ...      ...         ...
# 87484      0         454
# 87485      0         607
# 87486      0        1144
# 87487      0         248
# 87488      0         361
#
# [87091 rows x 9 columns]

# %% [markdown]
# - in column author "written by:" is written in each cell
# - in column narrator "Narratedby:" is written in each cell
# - 'Free' mentioned in some places in price column

# %%
audible_df['author']=audible_df['author'].str.split('Writtenby:').str.get(1)
audible_df['narrator']=audible_df['narrator'].str.split('Narratedby:').str.get(1)

# %%
audible_df
# Out:
#                                              name           author  \
# 0                      Geronimo Stilton #11 & #12  GeronimoStilton
# 1                                The Burning Maze      RickRiordan
# 2                                    The Deep End       JeffKinney
# 3                            Daughter of the Deep      RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      RickRiordan
# ...                                           ...              ...
# 87484                   Last Days of the Bus Club     ChrisStewart
# 87485                                    The Alps    StephenO'Shea
# 87486                        The Innocents Abroad        MarkTwain
# 87487                       A Sentimental Journey   LaurenceSterne
# 87488                                      Havana    MarkKurlansky
#
#              narrator releasedate language price(in INR) stars rating  \
# 0          BillLobely    04-08-08  English        468.00    5     34
# 1       RobbieDaymond    01-05-18  English        820.00  4.5     41
# 2          DanRussell    06-11-20  English        410.00  4.5     38
# 3      SoneelaNankani    05-10-21  English        615.00  4.5     12
# 4      JesseBernstein    13-01-10  English        820.00  4.5    181
# ...               ...         ...      ...           ...   ...    ...
# 87484    ChrisStewart    09-03-17  English        596.00     0      0
# 87485      RobertFass    21-02-17  English        820.00     0      0
# 87486       FloGibson    30-12-16  English        938.00     0      0
# 87487     AntonLesser    23-02-11  English        680.00     0      0
# 87488     FleetCooper    07-03-17  English        569.00     0      0
#
#        time(mins)
# 0             140
# 1             788
# 2             123
# 3             676
# 4             600
# ...           ...
# 87484         454
# 87485         607
# 87486        1144
# 87487         248
# 87488         361
#
# [87091 rows x 9 columns]

# %%
audible_df['price(in INR)']=audible_df['price(in INR)'].replace('Free','0')

# %%
audible_df[audible_df['price(in INR)']=='Free']
# Out:
# Empty DataFrame
# Columns: [name, author, narrator, releasedate, language, price(in INR), stars, rating, time(mins)]
# Index: []

# %% [markdown]
# - name in author and narrator there is no space between surname and first name

# %%
def split_names(val):
    # Handle NaN or blank values
    if pd.isna(val) or str(val).strip() == "":
        return val  
    
    val = str(val)  # make sure it's a string
    parts = val.split(",")
    cleaned_parts = []
    for p in parts:
        # insert space before capital letters (CamelCase → Camel Case)
        name = re.sub(r'(?<!^)(?=[A-Z])', ' ', p).strip()
        cleaned_parts.append(name)
    return ", ".join(cleaned_parts)

audible_df["narrator"] = audible_df["narrator"].apply(split_names)
audible_df["author"] = audible_df["author"].apply(split_names)

# %%
# replacing blank spaces in author and narrator column with no data avaliable
audible_df["author"] = audible_df["author"].replace(r'^\s*$', "No data available", regex=True)
audible_df["narrator"] = audible_df["narrator"].replace(r'^\s*$', "No data available", regex=True)

# %%
audible_df.sample(5)
# Out:
#                                    name  \
# 9906           Otto ja Dracon siepparit
# 4204   Step by Step 2 (Spanish Edition)
# 29423        The Mental Game of Trading
# 41074                    The War Queens
# 46674               Aristotle's Poetics
#
#                                       author                         narrator  \
# 9906                            Tapani Bagge                Valtteri Lehtinen
# 4204         Alison Lanthorn, Shelley Bolles  Alison Lanthorn, Shelley Bolles
# 29423                          Jared Tendler                    Jared Tendler
# 41074  Jonathan W. Jordan, Emily Anne Jordan                    Hillary Huber
# 46674                              Aristotle                       Ray Childs
#
#       releasedate language price(in INR) stars rating  time(mins)
# 9906     17-02-22  Finnish        166.00     0      0         254
# 4204     24-09-20  Spanish        115.00     0      0          46
# 29423    26-04-21  English        668.00  4.5      8          584
# 41074    10-03-20  English        937.00     0      0         929
# 46674    04-04-16  English        351.00    4      1           84

# %% [markdown]
# # last validity issue
# - incorrect datatype assigned to releasedate,price,stars,rating

# %%
audible_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87091 entries, 0 to 87488
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           87091 non-null  object
#  1   author         87074 non-null  object
#  2   narrator       85899 non-null  object
#  3   releasedate    87091 non-null  object
#  4   language       87091 non-null  object
#  5   price(in INR)  87091 non-null  object
#  6   stars          87091 non-null  object
#  7   rating         87091 non-null  object
#  8   time(mins)     87091 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 6.6+ MB

# %%
audible_df['price(in INR)']=audible_df['price(in INR)'].replace(",", "", regex=True).astype('float')
audible_df['stars']=audible_df['stars'].astype('float')
audible_df['rating']=audible_df['rating'].replace(",", "", regex=True).astype('int')
audible_df['releasedate']=pd.to_datetime(audible_df['releasedate'])
# Out:
# /tmp/ipykernel_639/4193765154.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   audible_df['releasedate']=pd.to_datetime(audible_df['releasedate'])

# %%
audible_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87091 entries, 0 to 87488
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           87091 non-null  object
#  1   author         87074 non-null  object
#  2   narrator       85899 non-null  object
#  3   releasedate    87091 non-null  datetime64[ns]
#  4   language       87091 non-null  object
#  5   price(in INR)  87091 non-null  float64
#  6   stars          87091 non-null  float64
#  7   rating         87091 non-null  int64
#  8   time(mins)     87091 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 6.6+ MB

# %%
audible_df.to_csv('audible_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 audible_df.to_csv('audible_cleaned.csv')
#
# File ~/venvs/data_analysis/lib/python3.10/site-packages/pandas/core/generic.py:3772, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3761 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3763 formatter = DataFrameFormatter(
#    3764     frame=df,
#    3765     header=header,
#    (...)
#    3769     decimal=decimal,
#    3770 )
# -> 3772 return DataFrameRenderer(formatter).to_csv(
#    3773     path_or_buf,
#    3774     lineterminator=lineterminator,
#    3775     sep=sep,
#    3776     encoding=encoding,
#    3777     errors=errors,
#    3778     compression=compression,
#    3779     quoting=quoting,
#    3780     columns=columns,
#    3781     index_label=index_label,
#    3782     mode=mode,
#    3783     chunksize=chunksize,
#    3784     quotechar=quotechar,
#    3785     date_format=date_format,
#    3786     doublequote=doublequote,
#    3787     escapechar=escapechar,
#    3788     storage_options=storage_options,
#    3789 )
#
# File ~/venvs/data_analysis/lib/python3.10/site-packages/pandas/io/formats/format.py:1186, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1165     created_buffer = False
#    1167 csv_formatter = CSVFormatter(
#    1168     path_or_buf=path_or_buf,
#    1169     lineterminator=lineterminator,
#    (...)
#    1184     formatter=self.fmt,
#    1185 )
# -> 1186 csv_formatter.save()
#    1188 if created_buffer:
#    1189     assert isinstance(path_or_buf, StringIO)
#
# File ~/venvs/data_analysis/lib/python3.10/site-packages/pandas/io/formats/csvs.py:240, in CSVFormatter.save(self)
#     236 """
#     237 Create the writer & save.
#     238 """
#     239 # apply compression and byte/text conversion
# --> 240 with get_handle(
#     241     self.filepath_or_buffer,
#     242     self.mode,
#     243     encoding=self.encoding,
#     244     errors=self.errors,
#     245     compression=self.compression,
#     246     storage_options=self.storage_options,
#     247 ) as handles:
#     248     # Note: self.encoding is irrelevant here
#     249     self.writer = csvlib.writer(
#     250         handles.handle,
#     251         lineterminator=self.lineterminator,
#    (...)
#     256         quotechar=self.quotechar,
#     257     )
#     259     self._save()
#
# File ~/venvs/data_analysis/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'audible_cleaned.csv'

# %%
audible_df.describe()
# Out:
#                          releasedate  price(in INR)         stars  \
# count                          87091   87091.000000  87091.000000
# mean   2018-06-26 03:46:26.340724224     558.940337      0.765200
# min              1998-12-27 00:00:00       0.000000      0.000000
# 25%              2016-09-08 00:00:00     268.000000      0.000000
# 50%              2020-01-31 00:00:00     585.000000      0.000000
# 75%              2021-08-04 00:00:00     755.000000      0.000000
# max              2025-11-14 00:00:00    7198.000000      5.000000
# std                              NaN     336.006195      1.707368
#
#              rating    time(mins)
# count  87091.000000  87091.000000
# mean       3.376675    417.365411
# min        0.000000      0.000000
# 25%        0.000000    142.000000
# 50%        0.000000    386.000000
# 75%        0.000000    584.000000
# max    12569.000000   8595.000000
# std       71.814930    364.497203
